# %% [markdown]
# <a href="https://colab.research.google.com/github/Mat9408/Ciencia_de_Dados_Praticas/blob/main/Ci%C3%AAncia_de_Dados_Aula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Praticar esse trecho no VsCode
import pandas as pd

# %%
dados = {
    'nome': ['Argentina', 'Brasil', 'França', 'Itália', 'Reino Unido'],
    'continente': ['América', 'América', 'Europa', 'Europa', 'Europa'],
    'extensao': [2780, 8511, 644, 301, 244],
    'corVerde': [0, 1, 0, 1, 0]
}

siglas = ['ARG', 'BRA', 'FRA', 'ITA', 'GBR']

paises = pd.DataFrame(dados, index=siglas)
print(paises)
# Out:
#             nome continente  extensao  corVerde
# ARG    Argentina    América      2780         0
# BRA       Brasil    América      8511         1
# FRA       França     Europa       644         0
# ITA       Itália     Europa       301         1
# GBR  Reino Unido     Europa       244         0

# %%
#Verificar número de linhas e colunas
paises.shape
# Out:
# (5, 4)

# %%
paises.index
# Out:
# Index(['ARG', 'BRA', 'FRA', 'ITA', 'GBR'], dtype='object')

# %%
paises.columns
# Out:
# Index(['nome', 'continente', 'extensao', 'corVerde'], dtype='object')
